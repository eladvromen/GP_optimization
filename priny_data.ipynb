# %%
import pandas as pd
import numpy as np
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI
llm = OpenAI('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')
pandas_ai = PandasAI(llm)


EXPERT_PATH = '..\\research\data_expert_demo.h5'

expert_data = pd.read_hdf(EXPERT_PATH)

# %%
expert_data.head()
pandas_ai.run(expert_data, prompt='Which are the songs with lowest bpm?')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 expert_data.head()
# ----> 2 pandas_ai.run(expert_data, prompt='Which are the songs with lowest bpm?')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandasai\__init__.py:103, in PandasAI.run(self, data_frame, prompt, is_conversational_answer, show_code, anonymize_df)
#     100 if anonymize_df:
#     101     df_head = anonymize_dataframe_head(df_head)
# --> 103 code = self._llm.generate_code(
#     104     self._task_instruction.format(
#     105         df_head=df_head,
#     106         rows_to_display=rows_to_display,
#     107         START_CODE_TAG=START_CODE_TAG,
#     108         END_CODE_TAG=END_CODE_TAG,
#     109     ),
#     110     prompt,
#     111 )
#     112 self._original_instruction_and_prompt = (
# ...

# %%
def map_noterange_to_songs(path, note_range):
    expert_data = pd.read_hdf(path)
    songs =expert_data["midi_filename"].unique()
    song_dict = {song: range for song, range in zip(songs, note_range)}

# %%
def add_note_range_column(songs_dict, expert_data):
    note_ranges = [songs_dict.get(filename) for filename in expert_data['midi_filename']]
    expert_data['note range'] = note_ranges

# %%
expert_data.head(25)
# Out:
#                  midi_filename      username practice_mode   bpm  \
# 0                    song1.mid   elad_demo_0    IMP_TIMING  75.0
# 1              83b_HaAviv.midi  elad_demo_01     IMP_PITCH  85.0
# 2              83b_HaAviv.midi  elad_demo_01     IMP_PITCH  85.0
# 3              83b_HaAviv.midi  elad_demo_01     IMP_PITCH  85.0
# 4              83b_HaAviv.midi  elad_demo_01    IMP_TIMING  85.0
# 5   86b_EmekHanaharHaadom.midi  elad_demo_02    IMP_TIMING  85.0
# 6   86b_EmekHanaharHaadom.midi  elad_demo_02     IMP_PITCH  85.0
# 7   86b_EmekHanaharHaadom.midi  elad_demo_02     IMP_PITCH  85.0
# 8   91b_LifneiShanimRabot.midi  elad_demo_03    IMP_TIMING  85.0
# 9   91b_LifneiShanimRabot.midi  elad_demo_03    IMP_TIMING  85.0
# 10           93a_ShirEres.midi  elad_demp_04     IMP_PITCH  85.0
# 11           93a_ShirEres.midi  elad_demp_04    IMP_TIMING  85.0
# 12       93b_HatulAlHagag.midi  elad_demo_05    IMP_TIMING  85.0
# ...

# %%
songs =expert_data["midi_filename"].unique()
songs
# Out:
# array(['song1.mid', '83b_HaAviv.midi', '86b_EmekHanaharHaadom.midi',
#        '91b_LifneiShanimRabot.midi', '93a_ShirEres.midi',
#        '93b_HatulAlHagag.midi', '97b_AchbarHizaher.midi'], dtype=object)

# %%
note_range = [5,11,8,9,8,7,9]
note_range = np.array(note_range)

# %%
song_dict = {song: range for song, range in zip(songs, note_range)}

# %%
path = '..\\research\data_expert_demo_new.h5'

# %%
expert_data_2 = pd.read_hdf(path)
songs_2 =expert_data_2["midi_filename"].unique()
songs_2
# Out:
# array(['74a_HaKovaSheli.midi', '77a_YomHuledetSameach.midi',
#        '85c_BnuGesher.midi', '86b_EmekHanaharHaadom.midi',
#        '91b_LifneiShanimRabot.midi'], dtype=object)

# %%
song_dict
# Out:
# {'song1.mid': 5,
#  '83b_HaAviv.midi': 11,
#  '86b_EmekHanaharHaadom.midi': 8,
#  '91b_LifneiShanimRabot.midi': 9,
#  '93a_ShirEres.midi': 8,
#  '93b_HatulAlHagag.midi': 7,
#  '97b_AchbarHizaher.midi': 9}

# %%
note_range_2 = [7, 9, 6, 8, 9]
note_range_2 = np.array(note_range_2)
song_dict_2 = {song_2: range for song_2, range in zip(songs_2, note_range_2)}

# %%
song_dict_2
# Out:
# {'74a_HaKovaSheli.midi': 7,
#  '77a_YomHuledetSameach.midi': 9,
#  '85c_BnuGesher.midi': 6,
#  '86b_EmekHanaharHaadom.midi': 8,
#  '91b_LifneiShanimRabot.midi': 9}

# %%
song_dict.update(song_dict_2)

# %%
song_dict
# Out:
# {'song1.mid': 5,
#  '83b_HaAviv.midi': 11,
#  '86b_EmekHanaharHaadom.midi': 8,
#  '91b_LifneiShanimRabot.midi': 9,
#  '93a_ShirEres.midi': 8,
#  '93b_HatulAlHagag.midi': 7,
#  '97b_AchbarHizaher.midi': 9,
#  '74a_HaKovaSheli.midi': 7,
#  '77a_YomHuledetSameach.midi': 9,
#  '85c_BnuGesher.midi': 6}

# %%
for key in song_dict:
    song_dict[key] = song_dict[key].tolist()

# %%
import json
#with open('song_dict.json', 'w') as f:
#    json.dump(song_dict, f)

# %%
song_dict
# Out:
# {'song1.mid': 5,
#  '83b_HaAviv.midi': 11,
#  '86b_EmekHanaharHaadom.midi': 8,
#  '91b_LifneiShanimRabot.midi': 9,
#  '93a_ShirEres.midi': 8,
#  '93b_HatulAlHagag.midi': 7,
#  '97b_AchbarHizaher.midi': 9,
#  '74a_HaKovaSheli.midi': 7,
#  '77a_YomHuledetSameach.midi': 9,
#  '85c_BnuGesher.midi': 6}

# %%
add_note_range_column(song_dict, expert_data)

# %%
expert_data.head()
# Out:
#      midi_filename      username practice_mode   bpm  \
# 0        song1.mid   elad_demo_0    IMP_TIMING  75.0
# 1  83b_HaAviv.midi  elad_demo_01     IMP_PITCH  85.0
# 2  83b_HaAviv.midi  elad_demo_01     IMP_PITCH  85.0
# 3  83b_HaAviv.midi  elad_demo_01     IMP_PITCH  85.0
# 4  83b_HaAviv.midi  elad_demo_01    IMP_TIMING  85.0
#
#    error_before_left_timing  error_before_right_timing  \
# 0                       0.0                   0.036429
# 1                       0.0                   0.078066
# 2                       0.0                   0.049352
# 3                       0.0                   0.040376
# 4                       0.0                   0.021390
#
#    error_before_left_pitch  error_before_right_pitch  error_after_left_timing  \
# 0                      0.0                  0.000000                      0.0
# 1                      0.0                  0.152778                      0.0
# ...
